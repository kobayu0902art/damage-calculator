# %%
import urllib
from bs4 import BeautifulSoup
import lxml.html
url = "https://yakkun.com/swsh/zukan/n810"
html=urllib.request.urlopen(url)
soup = BeautifulSoup(html, "lxml")
#soup.find('div',attrs={'class': 'main'}).text
#soup.find('div',attrs={'class': 'contents'}).text
left_table=soup.find('div',attrs={'class': 'table layout_left'}).text
right_table=soup.find('div',attrs={'class': 'table layout_right'}).text

#name
soup.find('tr',attrs={'class': 'head'}).text

#type
soup.find_all('ul',attrs={'class': 'type'})
soup.find_all('img')[4]
# Out:
# <img alt="くさ" src="//78npc3br.user.webaccel.jp/poke/xy_type/n11.gif"/>

# %%
#url = "https://yakkun.com/swsh/zukan/n825"
#html=urllib.request.urlopen(url)
#soup = BeautifulSoup(html, "lxml")
##soup.find('div',attrs={'class': 'main'}).text
##soup.find('div',attrs={'class': 'contents'}).text
#left_table=soup.find('div',attrs={'class': 'table layout_left'}).text
#right_table=soup.find('div',attrs={'class': 'table layout_right'}).text

##name
#soup.find('tr',attrs={'class': 'head'}).text

##type
#soup.find_all('ul',attrs={'class': 'type'})
#soup.find_all('img')
#soup.find_all('li')

#first_link_element = soup.find_all("li")
#first_link_element[4]

# %%
#url = "https://yakkun.com/swsh/zukan/n810"
#sample=urllib.request.urlopen(url)
#dom = lxml.html.fromstring(sample.read())
#dom.xpath('string(//*[@id="contents"]/div[2]/div[1]/table/tbody/tr[8]/td[2]/ul/li/a/img)')

#dom.xpath('string(//*[@id="contents"]/div[2]/div[1]/table/tbody/tr[1]/th)')
#dom.xpath('//*[@id="contents"]/div[2]/div[1]/table/tbody/tr[8]/td[2]/ul/li/a/img')

# %%
#basestats
soup.find_all('td')
# Out:
# [<td colspan="2"><img alt="サルノリ" height="96" src="//78npc3br.user.webaccel.jp/poke/icon96/n810.gif" width="96"/></td>,
#  <td class="c1">ガラルNo.</td>,
#  <td>001</td>,
#  <td class="c1" style="width:100px;">ぜんこくNo.</td>,
#  <td>810</td>,
#  <td class="c1">高さ</td>,
#  <td>0.3m</td>,
#  <td class="c1">重さ</td>,
#  <td><ul><li>5.0kg</li><li class="small">けたぐり威力20</li></ul></td>,
#  <td class="c1">タイプ</td>,
#  <td><ul class="type"><li><a href="/swsh/zukan/search/?type=11"><img alt="くさ" src="//78npc3br.user.webaccel.jp/poke/xy_type/n11.gif"/></a></li></ul></td>,
#  <td class="c1">英語名</td>,
#  <td><ul>Grookey</ul></td>,
# ...
